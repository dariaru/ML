# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("uk_universities (1).csv")

# %%
ds.head()
# Out:
#       Название университета              Регион  Год основания  \
# 0   University of Cambridge     East of England           1209
# 1      University of Oxford  South East England           1096
# 2  University of St Andrews            Scotland           1413
# 3   Imperial College London              London           1907
# 4   Loughborough University       East Midlands           1966
#
#                                                Девиз  Национальный ранг  \
# 0               From here, light and sacred draughts                  1
# 1                               The Lord is my light                  2
# 2                                      Ever to excel                  3
# 3  Knowledge is the adornment and safeguard of th...                  4
# 4                   With Truth, Knowledge and Labour                  5
#
#    Мировой рейтинг  Оценка мировых рейтингов  Minimum_IELTS_score  \
# 0                4                      94.1                  6.5
# 1                2                      93.3                  6.5
# 2               86                      75.8                  6.5
# 3                8                      86.6                  6.5
# 4              404                      72.8                  5.5
#
#   Иностранные студенты Оценка студентов  Кол-во поступивших студентов (тыс.)  \
# 0               20.20%           85.50%                                   20
# 1               16.80%           86.50%                                   25
# 2               40.40%           87.90%                                   10
# 3               41.40%           77.90%                                   15
# 4               22.00%           85.80%                                   15
#
#    Кол-во преподавательского состава Тип управления университета  \
# 0                             5000.0                      Public
# 1                             5000.0                      Public
# 2                             1500.0                      Public
# 3                             4000.0                      Public
# 4                             1500.0                      Public
#
#   Местоположение кампуса  Стоимость жизни в год   Широта  Долгота
# 0                  Urban                  12000  52.2054   0.1132
# 1                  Urban                  11500  51.7548  -1.2544
# 2               Suburban                  12000  56.3417  -2.7943
# 3                  Urban                  10700  51.4988  -0.1749
# 4               Suburban                   9398  52.7650  -1.2321

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Название университета                126 non-null    object
#  1   Регион                               126 non-null    object
#  2   Год основания                        126 non-null    int64
#  3   Девиз                                112 non-null    object
#  4   Национальный ранг                    126 non-null    int64
#  5   Мировой рейтинг                      126 non-null    int64
#  6   Оценка мировых рейтингов             82 non-null     float64
#  7   Minimum_IELTS_score                  126 non-null    float64
#  8   Иностранные студенты                 126 non-null    object
#  9   Оценка студентов                     126 non-null    object
#  10  Кол-во поступивших студентов (тыс.)  126 non-null    int64
#  11  Кол-во преподавательского состава    126 non-null    float64
#  12  Тип управления университета          126 non-null    object
#  13  Местоположение кампуса               109 non-null    object
#  14  Стоимость жизни в год                126 non-null    int64
#  15  Широта                               126 non-null    float64
#  16  Долгота                              126 non-null    object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 16.9+ KB

# %%
ds.describe().T
# Out:
#                                      count         mean          std  \
# Год основания                        126.0  1926.547619   140.208223
# Национальный ранг                    126.0    65.841270    38.522183
# Мировой рейтинг                      126.0  1063.674603  1108.226647
# Оценка мировых рейтингов              82.0    74.071951     6.364645
# Minimum_IELTS_score                  126.0     4.964286     0.626669
# Кол-во поступивших студентов (тыс.)  126.0    14.952381     8.760691
# Кол-во преподавательского состава    126.0  1386.440476  1202.583006
# Стоимость жизни в год                126.0  8661.238095  1565.332994
# Широта                               126.0    52.789456     1.652080
#
#                                            min       25%         50%  \
# Год основания                        1096.0000  1901.000  1966.50000
# Национальный ранг                       1.0000    32.250    65.00000
# Мировой рейтинг                         2.0000   187.750   685.50000
# Оценка мировых рейтингов               66.0000    68.725    72.60000
# Minimum_IELTS_score                     4.0000     4.500     4.50000
# Кол-во поступивших студентов (тыс.)     1.0000    10.000    15.00000
# Кол-во преподавательского состава       1.5000   625.000  1000.00000
# Стоимость жизни в год                5500.0000  7771.000  8217.00000
# Широта                                 50.1713    51.503    52.41285
#
#                                              75%         max
# Год основания                        1992.000000   2013.0000
# Национальный ранг                      99.500000    131.0000
# Мировой рейтинг                      1518.000000   5253.0000
# Оценка мировых рейтингов               77.700000     94.1000
# Minimum_IELTS_score                     5.500000      6.5000
# Кол-во поступивших студентов (тыс.)    20.000000     40.0000
# Кол-во преподавательского состава    1500.000000   5000.0000
# Стоимость жизни в год                9415.000000  15000.0000
# Широта                                 53.734075     57.1648

# %%
ds.isna().sum()
# Out:
# Название университета                   0
# Регион                                  0
# Год основания                           0
# Девиз                                  14
# Национальный ранг                       0
# Мировой рейтинг                         0
# Оценка мировых рейтингов               44
# Minimum_IELTS_score                     0
# Иностранные студенты                    0
# Оценка студентов                        0
# Кол-во поступивших студентов (тыс.)     0
# Кол-во преподавательского состава       0
# Тип управления университета             0
# Местоположение кампуса                 17
# Стоимость жизни в год                   0
# Широта                                  0
# Долгота                                 0
# dtype: int64

# %%
ds = ds.dropna()

# %%
ds.describe().T
# Out:
#                                      count         mean          std  \
# Год основания                         69.0  1889.695652   175.130649
# Национальный ранг                     69.0    45.405797    33.417290
# Мировой рейтинг                       69.0   422.173913   377.594241
# Оценка мировых рейтингов              69.0    74.772464     6.510238
# Minimum_IELTS_score                   69.0     5.202899     0.631984
# Кол-во поступивших студентов (тыс.)   69.0    19.057971     8.143717
# Кол-во преподавательского состава     69.0  1925.362319  1300.102462
# Стоимость жизни в год                 69.0  8768.913043  1547.970158
# Широта                                69.0    53.005233     1.728693
#
#                                            min       25%        50%  \
# Год основания                        1096.0000  1890.000  1962.0000
# Национальный ранг                       1.0000    19.000    36.0000
# Мировой рейтинг                         2.0000   119.000   342.0000
# Оценка мировых рейтингов               66.2000    68.900    73.8000
# Minimum_IELTS_score                     4.0000     4.500     5.5000
# Кол-во поступивших студентов (тыс.)     5.0000    15.000    15.0000
# Кол-во преподавательского состава     500.0000  1000.000  1500.0000
# Стоимость жизни в год                6000.0000  7771.000  8270.0000
# Широта                                 50.7371    51.517    52.4867
#
#                                            75%         max
# Год основания                        1967.0000   1997.0000
# Национальный ранг                      65.0000    120.0000
# Мировой рейтинг                       676.0000   1905.0000
# Оценка мировых рейтингов               79.7000     94.1000
# Minimum_IELTS_score                     5.5000      6.5000
# Кол-во поступивших студентов (тыс.)    25.0000     40.0000
# Кол-во преподавательского состава    2500.0000   5000.0000
# Стоимость жизни в год                9840.0000  12000.0000
# Широта                                 53.8067     57.1648

# %%
ds.isna().sum()
# Out:
# Название университета                  0
# Регион                                 0
# Год основания                          0
# Девиз                                  0
# Национальный ранг                      0
# Мировой рейтинг                        0
# Оценка мировых рейтингов               0
# Minimum_IELTS_score                    0
# Иностранные студенты                   0
# Оценка студентов                       0
# Кол-во поступивших студентов (тыс.)    0
# Кол-во преподавательского состава      0
# Тип управления университета            0
# Местоположение кампуса                 0
# Стоимость жизни в год                  0
# Широта                                 0
# Долгота                                0
# dtype: int64

# %%
# Out:
# Index(['brand', 'name', 'bodyType', 'color', 'fuelType', 'year', 'mileage',
#        'transmission', 'power', 'price', 'vehicleConfiguration', 'engineName',
#        'engineDisplacement', 'date', 'location', 'link', 'description',
#        'parse_date'],
#       dtype='object')

# %%
ds.columns
# Out:
# Index(['Название университета', 'Регион', 'Год основания', 'Девиз',
#        'Национальный ранг', 'Мировой рейтинг', 'Оценка мировых рейтингов',
#        'Minimum_IELTS_score', 'Иностранные студенты', 'Оценка студентов',
#        'Кол-во поступивших студентов (тыс.)',
#        'Кол-во преподавательского состава', 'Тип управления университета',
#        'Местоположение кампуса', 'Стоимость жизни в год', 'Широта', 'Долгота'],
#       dtype='object')

# %%
ds.columns=ds.columns.str.lower()

# %%
ds.columns
# Out:
# Index(['название университета', 'регион', 'год основания', 'девиз',
#        'национальный ранг', 'мировой рейтинг', 'оценка мировых рейтингов',
#        'minimum_ielts_score', 'иностранные студенты', 'оценка студентов',
#        'кол-во поступивших студентов (тыс.)',
#        'кол-во преподавательского состава', 'тип управления университета',
#        'местоположение кампуса', 'стоимость жизни в год', 'широта', 'долгота'],
#       dtype='object')

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
# Out:
# 0

# %%
int_types=["uint8","int8","int16"]
for it in int_types:
    print(np.iinfo(it))
# Out:
# Machine parameters for uint8
# ---------------------------------------------------------------
# min = 0
# max = 255
# ---------------------------------------------------------------
#
# Machine parameters for int8
# ---------------------------------------------------------------
# min = -128
# max = 127
# ---------------------------------------------------------------
#
# Machine parameters for int16
# ---------------------------------------------------------------
# min = -32768
# max = 32767
# ---------------------------------------------------------------

# %%
ds.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 0 to 114
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   название университета                69 non-null     object
#  1   регион                               69 non-null     object
#  2   год основания                        69 non-null     int64
#  3   девиз                                69 non-null     object
#  4   национальный ранг                    69 non-null     int64
#  5   мировой рейтинг                      69 non-null     int64
#  6   оценка мировых рейтингов             69 non-null     float64
#  7   minimum_ielts_score                  69 non-null     float64
#  8   иностранные студенты                 69 non-null     object
#  9   оценка студентов                     69 non-null     object
#  10  кол-во поступивших студентов (тыс.)  69 non-null     int64
#  11  кол-во преподавательского состава    69 non-null     float64
#  12  тип управления университета          69 non-null     object
#  13  местоположение кампуса               69 non-null     object
#  14  стоимость жизни в год                69 non-null     int64
#  15  широта                               69 non-null     float64
#  16  долгота                              69 non-null     object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 42.6 KB

# %%
for dtype in['float','int','object']:
    selected_dtype=ds.select_dtypes(include=[dtype])
    mean_usage_b=selected_dtype.memory_usage(deep=True).mean()
    mean_usage_mb=mean_usage_b/1024
    print("Average memory usage for {} columns: {:03.3f} КВ".format(dtype,mean_usage_mb))
# Out:
# Average memory usage for float columns: 0.539 КВ
# Average memory usage for int columns: 0.539 КВ
# Average memory usage for object columns: 4.200 КВ

# %%
def mem_usage(pandas_obj):
    if isinstance(pandas_obj,pd.DataFrame):
        usage_b=pandas_obj.memory_usage(deep=True).sum()
    else:
        usage_b=pandas_obj.memory_usage(deep=True)
    usage_mb=usage_b/1024
    return "{:03.3f} КВ".format(usage_mb)

# %%
ds_int=ds.select_dtypes(include=['int'])
converted_int = ds_int.apply(pd.to_numeric,downcast='unsigned')

print(mem_usage(ds_int))
print(mem_usage(converted_int))

compare_ints=pd.concat([ds_int.dtypes,converted_int.dtypes],axis=1)
compare_ints.columns=['before','after']
compare_ints.apply(pd.Series.value_counts)
# Out:
# 3.234 КВ
# 1.078 КВ
#         before  after
# uint8      NaN    2.0
# uint16     NaN    3.0
# int64      5.0    NaN

# %%
ds_float=ds.select_dtypes(include=['float'])
converted_float = ds_float.apply(pd.to_numeric,downcast='float')

print(mem_usage(ds_float))
print(mem_usage(converted_float))

compare_floats=pd.concat([ds_float.dtypes,converted_float.dtypes],axis=1)
compare_floats.columns=['before','after']
compare_floats.apply(pd.Series.value_counts)
# Out:
# 2.695 КВ
# 1.617 КВ
#          before  after
# float32     NaN    4.0
# float64     4.0    NaN

# %%
optimized_ds=ds.copy()

optimized_ds[converted_int.columns]=converted_int
optimized_ds[converted_float.columns]=converted_float

print(mem_usage(ds))
print(mem_usage(optimized_ds))
# Out:
# 42.647 КВ
# 39.413 КВ

# %%
ds_obj=ds.select_dtypes(include=['object']).copy()
ds_obj.describe().T
# Out:
#                             count unique                           top freq
# название университета          69     69       University of Cambridge    1
# регион                         69     12                        London   12
# девиз                          69     68  To know the causes of things    2
# иностранные студенты           69     63                        14.90%    3
# оценка студентов               69     51                        78.30%    4
# тип управления университета    69      1                        Public   69
# местоположение кампуса         69      3                         Urban   44
# долгота                        69     69                        0.1132    1

# %%
converted_obj=pd.DataFrame()
for col in ds_obj.columns:
    num_unique_values=len(ds_obj[col].unique())
    num_total_values=len(ds_obj[col])
    if num_unique_values / num_total_values<0.5:
        converted_obj.loc[:,col]=ds_obj[col].astype('category')
    else:
        converted_obj.loc[:,col]=ds_obj[col]

# %%
print(mem_usage(ds_obj))
print(mem_usage(converted_obj))

compare_obj=pd.concat([ds_obj.dtypes,converted_obj.dtypes],axis=1)
compare_obj.columns=['before','after']
compare_obj.apply(pd.Series.value_counts)
# Out:
# 37.796 КВ
# 26.344 КВ
#           before  after
# object       8.0      5
# category     NaN      1
# category     NaN      1
# category     NaN      1

# %%
optimized_ds[converted_obj.columns]=converted_obj
mem_usage(optimized_ds)
# Out:
# '27.961 КВ'

# %%
ds=optimized_ds

# %%
ds.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 0 to 114
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   название университета                69 non-null     object
#  1   регион                               69 non-null     category
#  2   год основания                        69 non-null     uint16
#  3   девиз                                69 non-null     object
#  4   национальный ранг                    69 non-null     uint8
#  5   мировой рейтинг                      69 non-null     uint16
#  6   оценка мировых рейтингов             69 non-null     float32
#  7   minimum_ielts_score                  69 non-null     float32
#  8   иностранные студенты                 69 non-null     object
#  9   оценка студентов                     69 non-null     object
#  10  кол-во поступивших студентов (тыс.)  69 non-null     uint8
#  11  кол-во преподавательского состава    69 non-null     float32
#  12  тип управления университета          69 non-null     category
#  13  местоположение кампуса               69 non-null     category
#  14  стоимость жизни в год                69 non-null     uint16
#  15  широта                               69 non-null     float32
#  16  долгота                              69 non-null     object
# dtypes: category(3), float32(4), object(5), uint16(3), uint8(2)
# memory usage: 28.0 KB

# %%
ds.sample(10)
# Out:
#                название университета                    регион  год основания  \
# 10                University of Bath        South West England           1966
# 31              University of Surrey        South East England           1966
# 22     University of East Anglia UEA           East of England           1963
# 2           University of St Andrews                  Scotland           1413
# 99            University of Bradford  Yorkshire and the Humber           1966
# 43            Aberystwyth University                     Wales           1872
# 79           University of Greenwich                    London           1890
# 25           University of Sheffield  Yorkshire and the Humber           1905
# 70  University of Central Lancashire        North West England           1992
# 46                  Aston University             West Midlands           1895
#
#                                               девиз  национальный ранг  \
# 10  Learn each field of study according to its kind                 11
# 31                     Wonderful things happen here                 32
# 22                                     Do different                 23
# 2                                     Ever to excel                  3
# 99                             Give invention light                105
# 43     A world without knowledge is no world at all                 45
# 79                      To learn, to do, to achieve                 84
# 25                     To know the causes of things                 26
# 70                        From the Earth to the Sun                 75
# 46                                          Forward                 48
#
#     мировой рейтинг  оценка мировых рейтингов  minimum_ielts_score  \
# 10              261                 74.800003                  5.5
# 31              342                 74.199997                  5.5
# 22              149                 77.099998                  5.5
# 2                86                 75.800003                  6.5
# 99             1392                 68.599998                  4.5
# 43              466                 71.000000                  4.5
# 79              747                 68.699997                  4.5
# 25               97                 79.900002                  5.5
# 70              804                 68.199997                  4.5
# 46              699                 70.500000                  5.5
#
#    иностранные студенты оценка студентов  кол-во поступивших студентов (тыс.)  \
# 10               21.70%           81.80%                                   15
# 31               24.40%           78.20%                                   15
# 22               20.20%           79.00%                                   15
# 2                40.40%           87.90%                                   10
# 99               14.90%           74.30%                                    9
# 43               13.10%           86.10%                                    7
# 79               14.90%           78.40%                                   15
# 25               21.50%           82.10%                                   30
# 70                8.50%           78.70%                                   20
# 46               16.50%           77.30%                                   10
#
#     кол-во преподавательского состава тип управления университета  \
# 10                             1000.0                      Public
# 31                             1000.0                      Public
# 22                             1500.0                      Public
# 2                              1500.0                      Public
# 99                              500.0                      Public
# 43                              750.0                      Public
# 79                             1000.0                      Public
# 25                             3000.0                      Public
# 70                             1500.0                      Public
# 46                              850.0                      Public
#
#    местоположение кампуса  стоимость жизни в год     широта  долгота
# 10               Suburban                  11000  51.378201  -2.3264
# 31               Suburban                  10700  51.243099  -0.5895
# 22               Suburban                   9840  52.622101   Jan-11
# 2                Suburban                  12000  56.341702  -2.7943
# 99                  Urban                   8270  53.791500  -1.7661
# 43               Suburban                   7771  52.418301  -4.0639
# 79               Suburban                  10229  51.483002  -0.0064
# 25                  Urban                   7200  53.381401  -1.4884
# 70                  Urban                   7500  53.764500  -2.7083
# 46                  Urban                   6000  52.486698  -1.8882

# %%
ds['Отношение Национал. рейтинга к мировому'] = ds['национальный ранг'] /ds['мировой рейтинг']

# %%
ds.head()
# Out:
#       название университета              регион  год основания  \
# 0   University of Cambridge     East of England           1209
# 1      University of Oxford  South East England           1096
# 2  University of St Andrews            Scotland           1413
# 3   Imperial College London              London           1907
# 4   Loughborough University       East Midlands           1966
#
#                                                девиз  национальный ранг  \
# 0               From here, light and sacred draughts                  1
# 1                               The Lord is my light                  2
# 2                                      Ever to excel                  3
# 3  Knowledge is the adornment and safeguard of th...                  4
# 4                   With Truth, Knowledge and Labour                  5
#
#    мировой рейтинг  оценка мировых рейтингов  minimum_ielts_score  \
# 0                4                 94.099998                  6.5
# 1                2                 93.300003                  6.5
# 2               86                 75.800003                  6.5
# 3                8                 86.599998                  6.5
# 4              404                 72.800003                  5.5
#
#   иностранные студенты оценка студентов  кол-во поступивших студентов (тыс.)  \
# 0               20.20%           85.50%                                   20
# 1               16.80%           86.50%                                   25
# 2               40.40%           87.90%                                   10
# 3               41.40%           77.90%                                   15
# 4               22.00%           85.80%                                   15
#
#    кол-во преподавательского состава тип управления университета  \
# 0                             5000.0                      Public
# 1                             5000.0                      Public
# 2                             1500.0                      Public
# 3                             4000.0                      Public
# 4                             1500.0                      Public
#
#   местоположение кампуса  стоимость жизни в год     широта  долгота  \
# 0                  Urban                  12000  52.205399   0.1132
# 1                  Urban                  11500  51.754799  -1.2544
# 2               Suburban                  12000  56.341702  -2.7943
# 3                  Urban                  10700  51.498798  -0.1749
# 4               Suburban                   9398  52.764999  -1.2321
#
#    Отношение Национал. рейтинга к мировому
# 0                                 0.250000
# 1                                 1.000000
# 2                                 0.034884
# 3                                 0.500000
# 4                                 0.012376

# %%
ax = sns.displot(data=ds,x='регион',color='blue',bins=20,kde=True)
ax.fig.set_figheight(10)
ax.fig.set_figwidth(10)
plt.xticks(rotation=90)
plt.title('Количество институтов в регионе')
plt.xlabel('Регион')
plt.ylabel('Количество')
# Out:
# Text(13.819444444444445, 0.5, 'Количество')

# %%
top_positions = ds.groupby('кол-во преподавательского состава')['кол-во преподавательского состава'].count()
positions = top_positions.index

# %%
plt.figure(figsize=(20,7))
plt.pie(x=top_positions, labels=positions, autopct="%.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x21102fd9b90>,
#   <matplotlib.patches.Wedge at 0x2110300be50>,
#   <matplotlib.patches.Wedge at 0x211030153d0>,
#   <matplotlib.patches.Wedge at 0x21103016a50>,
#   <matplotlib.patches.Wedge at 0x21103028090>,
#   <matplotlib.patches.Wedge at 0x211030297d0>,
#   <matplotlib.patches.Wedge at 0x2110302af90>,
#   <matplotlib.patches.Wedge at 0x21103194550>,
#   <matplotlib.patches.Wedge at 0x21103028190>,
#   <matplotlib.patches.Wedge at 0x21103197090>,
#   <matplotlib.patches.Wedge at 0x211031a8710>,
#   <matplotlib.patches.Wedge at 0x211031a9d50>,
#   <matplotlib.patches.Wedge at 0x211031ab3d0>,
#   <matplotlib.patches.Wedge at 0x211031b8a90>,
#   <matplotlib.patches.Wedge at 0x211031ba190>,
#   <matplotlib.patches.Wedge at 0x211031bb910>],
#  [Text(1.098860040968941, 0.0500660599781685, '500.0'),
#   Text(1.0897545402588844, 0.14978331677843057, '600.0'),
#   Text(1.071618989888122, 0.24825942179736302, '700.0'),
#   Text(1.0278332182181056, 0.391865889721742, '750.0'),
#   Text(0.9398613391846532, 0.5715423546037779, '800.0'),
#   Text(0.8208020444956139, 0.732314142804726, '850.0'),
#   Text(0.6745934105749741, 0.8688634705227425, '900.0'),
#   Text(0.5499999814184447, 0.9526279548909484, '950.0'),
#   Text(-0.32081055767140587, 1.0521789705589832, '1000.0'),
#   Text(-1.0716189811717247, -0.24825945942194197, '1500.0'),
#   Text(-0.5060714873343501, -0.9766737683111997, '2000.0'),
#   Text(-0.1745507344174617, -1.086062632224461, '2500.0'),
#   Text(0.36836763456731464, -1.036486992587597, '3000.0'),
#   Text(0.7134403437104184, -0.8372591450479119, '3500.0'),
#   Text(0.853282459690507, -0.6941966896957363, '4000.0'),
#   Text(1.0592090354121189, -0.2967763792846874, '5000.0')],
#  [Text(0.5993782041648769, 0.027308759988091905, '1.45'),
#   Text(0.5944115674139369, 0.08169999097005304, '1.45'),
#   Text(0.5845194490298847, 0.1354142300712889, '1.45'),
#   Text(0.5606363008462394, 0.2137450307573138, '2.90'),
#   Text(0.5126516395552653, 0.3117503752384243, '2.90'),
#   Text(0.44771020608851664, 0.39944407789348685, '2.90'),
#   Text(0.367960042131804, 0.4739255293760413, '2.90'),
#   Text(0.2999999898646062, 0.5196152481223354, '1.45'),
#   Text(-0.1749875769116759, 0.5739158021230817, '24.64'),
#   Text(-0.5845194442754862, -0.1354142505937865, '23.19'),
#   Text(-0.2760389930914637, -0.5327311463515634, '4.35'),
#   Text(-0.09520949150043363, -0.5923977993951606, '5.80'),
#   Text(0.2009278006730807, -0.5653565414114166, '10.14'),
#   Text(0.38914927838750096, -0.45668680638977005, '1.45'),
#   Text(0.4654267961948219, -0.37865273983403797, '4.35'),
#   Text(0.5777503829520648, -0.16187802506437496, '8.70')])

# %%
min_price = ds.pivot_table(index='регион',
                           values='национальный ранг',
                           aggfunc='min').sort_values(by='стоимость жизни в год')
plt.figure(figsize=(20,4))
sns.barplot(x=min_price.index,y=min_price['стоимость жизни в год'])
plt.title('Минимальная стоимость жизни в год в определённом регионе')
plt.xlabel('Регион')
plt.ylabel('Стоимость')
# Out:
# Text(0, 0.5, 'Стоимость')

# %%
min_price = ds.pivot_table(index='название университета',
                           values='оценка мировых рейтингов',
                           aggfunc='min').sort_values(by='оценка мировых рейтингов')
plt.figure(figsize=(20,4))
plt.xticks(rotation=90)
sns.barplot(x=min_price.index,y=min_price['оценка мировых рейтингов'])
plt.title('Максимальные рейтинг по миру')
plt.xlabel('Университеты')
plt.ylabel('Мировой рейтинг')
# Out:
# Text(0, 0.5, 'Мировой рейтинг')

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=mean_foul)
sns.set_style('darkgrid')
plt.title('Среднее цена за пробег')
plt.xlabel('Пробег')
plt.ylabel('Цена')
plt.legend('')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 plt.figure(figsize=(18,6))
# ----> 2 sns.lineplot(data=mean_foul)
#       3 sns.set_style('darkgrid')
#       4 plt.title('Среднее цена за пробег')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\relational.py:423, in _LinePlotter.plot(self, ax, kws)
#     415 # TODO How to handle NA? We don't want NA to propagate through to the
#     416 # estimate/CI when some values are present, but we would also like
#     417 # matplotlib to show "gaps" in the line when all values are missing.
#    (...)
#     420
#     421 # Loop over the semantic subsets and add to the plot
#     422 grouping_vars = "hue", "size", "style"
# --> 423 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     425     if self.sort:
#     426         sort_vars = ["units", orient, other]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1065, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#    1062 for var in grouping_vars:
#    1063     grouping_keys.append(levels.get(var, []))
# -> 1065 iter_keys = itertools.product(*grouping_keys)
#    1066 if reverse:
#    1067     iter_keys = reversed(list(iter_keys))
#
# TypeError: 'NoneType' object is not iterable

# %%
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(ds.corr(),annot = True)
# Out:
# C:\Users\noski\AppData\Local\Temp\ipykernel_3328\1162311783.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr(),annot = True)
# <AxesSubplot: >

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 ds=swimmer_data()
#       2 xs = ds['Цена']
#       3 ys = ds['Лошадиные силы'].apply( np.log )
#
# Cell In[42], line 3, in swimmer_data()
#       1 def swimmer_data():
# ----> 3     ds = load_data()
#       4     return ds[ds['Вид марки'] == 'Toyota'].dropna()
#
# NameError: name 'load_data' is not defined
